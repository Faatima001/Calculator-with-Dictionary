# %%
def add(n1, n2):
    return n1 + n2

def substract(n1, n2):
    return n1 - n2

def multiply(n1, n2):
    return n1 * n2

def divide(n1, n2):
    return n1 / n2

#Add these 4 functions into a dictionary as the values
operations = {
    "+": add,
    "-": substract,
    "*": multiply,
    "/": divide
}

#Use dictionary operations to perform the calculations.

# print(operations["*"](4,8))

def calculator():

    should_accumulate = True
    num1 = float(input("What is the first number?: "))

    while should_accumulate:

        for symbol in operations:
            print(symbol)

        operation_symbol = input("Pick an operation: ")
        num2 = float(input("What is the next number?: "))
        answer = operations[operation_symbol](num1, num2)

        print(f"{num1} {operation_symbol} {num2} = {answer}")

        choice = input(f"Type 'y' to continue calculating with {answer}, or type n to start a new calculation")

        if choice == 'y':
            num1 == answer
        else:
            should_accumulate = False
            print("\n" * 20)
            calculator()

calculator()
# Out:
# +
# -
# *
# /
# 3.0 + 4.0 = 7.0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# +
# -
# *
# /
# 3.0 * 1.0 = 3.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 50
#      47             print("\n" * 20)
#      48             calculator()
# ---> 50 calculator()
#
# Cell In[13], line 48, in calculator()
#      46 should_accumulate = False
#      47 print("\n" * 20)
# ---> 48 calculator()
#
# Cell In[13], line 48, in calculator()
#      46 should_accumulate = False
#      47 print("\n" * 20)
# ---> 48 calculator()
#
# Cell In[13], line 28, in calculator()
#      25 def calculator():
#      27     should_accumulate = True
# ---> 28     num1 = float(input("What is the first number?: "))
#      30     while should_accumulate:
#      32         for symbol in operations:
#
# ValueError: could not convert string to float: 'Escape'
